# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Cu2O.csv')
df
# Out:
#          wl_1  ref_1_ND64    wl_2  ref_2_ND64    wl_3  ref_3_ND64  \
# 0      400.00    0.038718  560.00    0.679230  610.00    0.768373
# 1      400.02    0.038060  560.05    0.681459  610.05    0.764559
# 2      400.04    0.038389  560.10    0.681762  610.10    0.768620
# 3      400.06    0.036086  560.15    0.679740  610.15    0.766565
# 4      400.08    0.040034  560.20    0.678098  610.20    0.767167
# ...       ...         ...     ...         ...     ...         ...
# 14996  699.92    0.731219     NaN         NaN     NaN         NaN
# 14997  699.94    0.713783     NaN         NaN     NaN         NaN
# 14998  699.96    0.719705     NaN         NaN     NaN         NaN
# 14999  699.98    0.729245     NaN         NaN     NaN         NaN
# 15000  700.00    0.732535     NaN         NaN     NaN         NaN
#
#        Cu2O_1_77K_ND4  Cu2O_2_77K_ND1  Cu2O_3_77K_ND4  Cu2O_1_150K_ND4  \
# 0           -0.034315        0.435593        0.926527        -0.026091
# ...

# %%
plt.figure()
ax = df.plot('wl_1', 'ref_1_ND64')
df.plot('wl_1', 'Cu2O_1_77K_ND4', ax=ax)
df.plot('wl_1', 'Cu2O_1_150K_ND4', ax=ax)
df.plot('wl_1', 'Cu2O_1_296K_ND4', ax=ax)
df.plot('wl_1', 'BG_1_ND4', ax=ax)
plt.show()

# %%
df.mean()
# Out:
# wl_1               550.000000
# ref_1_ND64           0.516550
# wl_2               572.500000
# ref_2_ND64           0.711759
# wl_3               615.000000
# ref_3_ND64           0.773507
# Cu2O_1_77K_ND4       0.387628
# Cu2O_2_77K_ND1       0.725241
# Cu2O_3_77K_ND4       0.970730
# Cu2O_1_150K_ND4      0.389804
# Cu2O_1_296K_ND4      0.310586
# BG_23_ND64          -0.046062
# BG_1_ND4            -0.048067
# dtype: float64

# %%
BG_1 = -0.048067
BG_23 = -0.046062

# %%
df['T_1_77K'] = (df['Cu2O_1_77K_ND4']/0.23 - BG_1/0.23)/(df['ref_1_ND64']/0.13/0.13 - BG_1/0.23) 
df['T_1_150K'] = (df['Cu2O_1_150K_ND4']/0.23 - BG_1/0.23)/(df['ref_1_ND64']/0.13/0.13 - BG_1/0.23) 
df['T_1_296K'] = (df['Cu2O_1_296K_ND4']/0.23 - BG_1/0.23)/(df['ref_1_ND64']/0.13/0.13 - BG_1/0.23)
df
# Out:
#          wl_1  ref_1_ND64    wl_2  ref_2_ND64    wl_3  ref_3_ND64  \
# 0      400.00    0.038718  560.00    0.679230  610.00    0.768373
# 1      400.02    0.038060  560.05    0.681459  610.05    0.764559
# 2      400.04    0.038389  560.10    0.681762  610.10    0.768620
# 3      400.06    0.036086  560.15    0.679740  610.15    0.766565
# 4      400.08    0.040034  560.20    0.678098  610.20    0.767167
# ...       ...         ...     ...         ...     ...         ...
# 14996  699.92    0.731219     NaN         NaN     NaN         NaN
# 14997  699.94    0.713783     NaN         NaN     NaN         NaN
# 14998  699.96    0.719705     NaN         NaN     NaN         NaN
# 14999  699.98    0.729245     NaN         NaN     NaN         NaN
# 15000  700.00    0.732535     NaN         NaN     NaN         NaN
#
#        Cu2O_1_77K_ND4  Cu2O_2_77K_ND1  Cu2O_3_77K_ND4  Cu2O_1_150K_ND4  \
# 0           -0.034315        0.435593        0.926527        -0.026091
# ...

# %%
plt.figure()
ax = df.plot('wl_1', 'T_1_296K', label=r'296 K')
df.plot('wl_1', 'T_1_150K', ax=ax, label=r'150 K')
df.plot('wl_1', 'T_1_77K', ax=ax, label=r'77 K')

#plt.xlim(400,700)
plt.xlim(560,660)
#plt.ylim(-0.02,0.12)
plt.ylim(0,0.13)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Transmittance')

plt.grid()
plt.legend()
plt.show()

# %%
df.columns
# Out:
# Index(['wl_1', 'ref_1_ND64', 'wl_2', 'ref_2_ND64', 'wl_3', 'ref_3_ND64',
#        'Cu2O_1_77K_ND4', 'Cu2O_2_77K_ND1', 'Cu2O_3_77K_ND4', 'Cu2O_1_150K_ND4',
#        'Cu2O_1_296K_ND4', 'BG_23_ND64', 'BG_1_ND4', 'T_1_77K', 'T_1_150K',
#        'T_1_296K'],
#       dtype='object')

# %%
plt.figure()
ax = df.plot('wl_2', 'ref_2_ND64')
df.plot('wl_2', 'Cu2O_2_77K_ND1', ax=ax)
df.plot('wl_2', 'BG_23_ND64', ax=ax)
plt.show()

# %%
df['T_2_77K'] = (df['Cu2O_2_77K_ND1'] - BG_23/0.13/0.13)/(df['ref_2_ND64']/0.13/0.13 - BG_23/0.13/0.13)

# %%
plt.figure()
ax = df.plot('wl_2', 'T_2_77K')
plt.show()

# %%
df.columns
# Out:
# Index(['wl_1', 'ref_1_ND64', 'wl_2', 'ref_2_ND64', 'wl_3', 'ref_3_ND64',
#        'Cu2O_1_77K_ND4', 'Cu2O_2_77K_ND1', 'Cu2O_3_77K_ND4', 'Cu2O_1_150K_ND4',
#        'Cu2O_1_296K_ND4', 'BG_23_ND64', 'BG_1_ND4', 'T_1_77K', 'T_1_150K',
#        'T_1_296K', 'T_2_77K'],
#       dtype='object')

# %%
plt.figure()
ax = df.plot('wl_3', 'ref_3_ND64')
df.plot('wl_3', 'Cu2O_3_77K_ND4', ax=ax)
df.plot('wl_3', 'BG_23_ND64', ax=ax)
plt.show()

# %%
df['T_3_77K'] = (df['Cu2O_3_77K_ND4']/0.23 - BG_23/0.13/0.13)/(df['ref_3_ND64']/0.13/0.13 - BG_23/0.13/0.13)

# %%
plt.figure()
ax = df.plot('wl_3', 'T_3_77K')
plt.show()

# %%
df['OD_1_77K'] = - np.log10(df['T_1_77K'])
df['OD_1_150K'] = - np.log10(df['T_1_150K'])
df['OD_1_296K'] = - np.log10(df['T_1_296K'])
df.head()
# Out:
# C:\Users\shun-\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#      wl_1  ref_1_ND64    wl_2  ref_2_ND64    wl_3  ref_3_ND64  Cu2O_1_77K_ND4  \
# 0  400.00    0.038718  560.00    0.679230  610.00    0.768373       -0.034315
# 1  400.02    0.038060  560.05    0.681459  610.05    0.764559       -0.034315
# 2  400.04    0.038389  560.10    0.681762  610.10    0.768620       -0.036289
# 3  400.06    0.036086  560.15    0.679740  610.15    0.766565       -0.030038
# 4  400.08    0.040034  560.20    0.678098  610.20    0.767167       -0.033328
#
#    Cu2O_2_77K_ND1  Cu2O_3_77K_ND4  Cu2O_1_150K_ND4  ...  BG_23_ND64  BG_1_ND4  \
# 0        0.435593        0.926527        -0.026091  ...   -0.046590 -0.075108
# ...

# %%
df['E_1'] = 1239.8/(df['wl_1'] + 1.7)
df['E_2'] = 1239.8/(df['wl_2'] + 1.7)
df['E_3'] = 1239.8/(df['wl_3'] + 1.7)
df
# Out:
#          wl_1  ref_1_ND64    wl_2  ref_2_ND64    wl_3  ref_3_ND64  \
# 0      400.00    0.038718  560.00    0.679230  610.00    0.768373
# 1      400.02    0.038060  560.05    0.681459  610.05    0.764559
# 2      400.04    0.038389  560.10    0.681762  610.10    0.768620
# 3      400.06    0.036086  560.15    0.679740  610.15    0.766565
# 4      400.08    0.040034  560.20    0.678098  610.20    0.767167
# ...       ...         ...     ...         ...     ...         ...
# 14996  699.92    0.731219     NaN         NaN     NaN         NaN
# 14997  699.94    0.713783     NaN         NaN     NaN         NaN
# 14998  699.96    0.719705     NaN         NaN     NaN         NaN
# 14999  699.98    0.729245     NaN         NaN     NaN         NaN
# 15000  700.00    0.732535     NaN         NaN     NaN         NaN
#
#        Cu2O_1_77K_ND4  Cu2O_2_77K_ND1  Cu2O_3_77K_ND4  Cu2O_1_150K_ND4  ...  \
# 0           -0.034315        0.435593        0.926527        -0.026091  ...
# ...

# %%
plt.figure()
ax = df.plot('E_1', 'OD_1_296K', label=r'296 K')
df.plot('E_1', 'OD_1_150K', ax=ax, label=r'150 K')
df.plot('E_1', 'OD_1_77K', ax=ax, label=r'77 K')
plt.xlim(1.8, 2.4)
plt.ylim(0.80, 2.2)
plt.xlabel(r'Energy (eV)')
plt.ylabel(r'O.D.')
plt.grid()
plt.legend()
plt.show()

# %%
df.query('2.13<E_1<2.15 & OD_1_77K > 1.8')
# Out:
#         wl_1  ref_1_ND64  wl_2  ref_2_ND64  wl_3  ref_3_ND64  Cu2O_1_77K_ND4  \
# 8888  577.76    0.708519   NaN         NaN   NaN         NaN        0.096619
# 8893  577.86    0.720363   NaN         NaN   NaN         NaN        0.107804
# 8900  578.00    0.709835   NaN         NaN   NaN         NaN        0.094974
# 8907  578.14    0.715757   NaN         NaN   NaN         NaN        0.104514
#
#       Cu2O_2_77K_ND1  Cu2O_3_77K_ND4  Cu2O_1_150K_ND4  ...  T_1_150K  \
# 8888             NaN             NaN         0.068326  ...  0.012011
# 8893             NaN             NaN         0.064379  ...  0.011414
# 8900             NaN             NaN         0.068655  ...  0.012023
# 8907             NaN             NaN         0.066681  ...  0.011722
#
#       T_1_296K  T_2_77K  T_3_77K  OD_1_77K  OD_1_150K  OD_1_296K       E_1  \
# 8888  0.013810      NaN      NaN  1.825926   1.920425   1.859802  2.139578
# 8893  0.011714      NaN      NaN  1.800751   1.942573   1.931288  2.139209
# ...

# %%
df['OD_2_77K'] = - np.log10(df['T_2_77K'])
df['OD_3_77K'] = - np.log10(df['T_3_77K'])

# %%
plt.figure()

ax = df.plot('E_2', 'OD_2_77K', legend=False)

X = np.linspace(2.14,2.17)
func = lambda x: 3*(x-2.155)+1.13
plt.plot(X,func(X))

plt.xlabel(r'Energy (eV)')
plt.ylabel(r'O.D.')
plt.xlim(2.15,2.162)
plt.ylim(1.12,1.16)
#plt.xlim(2.12,2.18)
#plt.xlim(2.15,2.16)
#plt.ylim(1.04,1.16)
#plt.ylim(1.14,1.16)
plt.grid()
#plt.legend()
plt.show()

# %%
df['OD_clear'] = df['OD_2_77K'] - func(df['E_2'])

ax = df.plot.scatter('E_2', 'OD_clear', legend=False)

plt.xlabel(r'Energy (eV)')
plt.ylabel(r'O.D.')
plt.xlim(2.15,2.16)
plt.ylim(-0.01,0.03)
#plt.xlim(2.157,2.162)
#plt.xlim(2.15,2.16)
#plt.ylim(-0.02,0.01)
#plt.ylim(1.14,1.16)
plt.grid()
#plt.legend()
plt.show()

# %%
df.query('2.158 < E_2 < 2.160')
# Out:
#        wl_1  ref_1_ND64    wl_2  ref_2_ND64  wl_3  ref_3_ND64  Cu2O_1_77K_ND4  \
# 246  404.92    0.051548  572.30    0.710991   NaN         NaN       -0.029380
# 247  404.94    0.049246  572.35    0.712415   NaN         NaN       -0.029709
# 248  404.96    0.044969  572.40    0.710175   NaN         NaN       -0.025762
# 249  404.98    0.047930  572.45    0.712399   NaN         NaN       -0.027736
# 250  405.00    0.051877  572.50    0.713315   NaN         NaN       -0.026420
# 251  405.02    0.053193  572.55    0.714531   NaN         NaN       -0.028393
# 252  405.04    0.050233  572.60    0.712833   NaN         NaN       -0.027736
# 253  405.06    0.051219  572.65    0.713296   NaN         NaN       -0.039250
# 254  405.08    0.052864  572.70    0.712344   NaN         NaN       -0.035631
# 255  405.10    0.045956  572.75    0.712486   NaN         NaN       -0.026091
# 256  405.12    0.045298  572.80    0.715031   NaN         NaN       -0.029709
#
# ...

# %%
half = 0.007575/2
print(half)
# Out:
# 0.0037875

# %%
df.query('0.006 > OD_clear> 0.002 & 2.154 < E_2 < 2.160')
# Out:
#        wl_1  ref_1_ND64    wl_2  ref_2_ND64  wl_3  ref_3_ND64  Cu2O_1_77K_ND4  \
# 259  405.18    0.033455  572.95    0.715278   NaN         NaN       -0.027736
# 260  405.20    0.059773  573.00    0.716070   NaN         NaN       -0.029380
# 261  405.22    0.048917  573.05    0.715604   NaN         NaN       -0.023459
# 268  405.36    0.050233  573.40    0.714799   NaN         NaN       -0.029051
# 269  405.38    0.052535  573.45    0.715520   NaN         NaN       -0.030367
# 270  405.40    0.058457  573.50    0.714731   NaN         NaN       -0.028064
# 272  405.44    0.049575  573.60    0.715365   NaN         NaN       -0.030038
#
#      Cu2O_2_77K_ND1  Cu2O_3_77K_ND4  Cu2O_1_150K_ND4  ...  T_3_77K  OD_1_77K  \
# 259        0.540435             NaN        -0.021156  ...      NaN  1.393730
# 260        0.538237             NaN        -0.027736  ...      NaN  1.663739
# 261        0.532834             NaN        -0.022472  ...      NaN  1.462501
# ...

# %%
2.159366-2.158614
# Out:
# 0.0007519999999998639

# %%
plt.figure()
ax = df.plot('E_3', 'OD_3_77K', legend=False)
plt.xlim(2.0,2.027)
plt.ylim(0.835,0.860)
plt.xlabel(r'Energy (eV)')
plt.ylabel(r'O.D.')
plt.grid()
#plt.legend()
plt.show()

# %%
df.query('OD_3_77K > 0.8545')
# Out:
#       wl_1  ref_1_ND64    wl_2  ref_2_ND64    wl_3  ref_3_ND64  \
# 12  400.24    0.037073  560.60    0.682783  610.60    0.772012
# 22  400.44    0.037073  561.10    0.686441  611.10    0.772005
# 23  400.46    0.041021  561.15    0.685172  611.15    0.772120
# 24  400.48    0.036086  561.20    0.686291  611.20    0.770415
# 25  400.50    0.039047  561.25    0.687125  611.25    0.770086
# 26  400.52    0.036744  561.30    0.686844  611.30    0.771281
#
#     Cu2O_1_77K_ND4  Cu2O_2_77K_ND1  Cu2O_3_77K_ND4  Cu2O_1_150K_ND4  ...  \
# 12       -0.035960        0.438025        0.928743        -0.049119  ...
# 22       -0.032341        0.439373        0.927683        -0.026420  ...
# 23       -0.043527        0.439583        0.925517        -0.024117  ...
# 24       -0.027407        0.441007        0.924317        -0.026091  ...
# 25       -0.027078        0.439423        0.925619        -0.023130  ...
# 26       -0.032012        0.439520        0.925259        -0.023788  ...
#
# ...

# %%
#エラー計算
E = 1
dE = 10*10**(-3)
dlam = 1239.8*dE/E**2
print(dlam)
# Out:
# 12.398
