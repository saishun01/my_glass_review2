# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
df = pd.read_csv('f_hg_434-6.csv')
df
# Out:
#          wl     2ms_1     2ms_2   200ms_1   200ms_2     thr_1     thr_2
# 0    434.00 -0.006023 -0.006681 -0.011945 -0.007997  0.043324 -0.068529
# 1    434.02 -0.004049 -0.007997 -0.007997 -0.008655  0.064708  0.003189
# 2    434.04 -0.001417 -0.005694 -0.009971 -0.007997  0.174587 -0.091886
# 3    434.06 -0.003062 -0.008655 -0.010958 -0.007997 -0.290919  0.192680
# 4    434.08 -0.001746 -0.007668 -0.010629 -0.008655  0.148268  0.036415
# ..      ...       ...       ...       ...       ...       ...       ...
# 96   435.92 -0.001746 -0.007339 -0.008326 -0.008326 -0.099124  0.132477
# 97   435.94 -0.001088 -0.006023 -0.007339 -0.007997 -0.038592 -0.203081
# 98   435.96 -0.003391 -0.004707 -0.006681 -0.009971 -0.015234  0.362434
# 99   435.98 -0.007010 -0.010629 -0.008655 -0.009313  0.045298  0.141689
# 100  436.00  0.001544 -0.007668 -0.008984 -0.009313  0.104185 -0.163604
#
# [101 rows x 7 columns]

# %%
plt.figure()
ax = df.plot('wl', '2ms_1')
df.plot('wl', '2ms_2', ax=ax)
plt.show()

# %%
plt.figure()
ax = df.plot('wl', '200ms_1')
df.plot('wl', '200ms_2', ax=ax)
plt.show()

# %%
plt.figure()
ax = df.plot('wl', 'thr_1')
df.plot('wl', 'thr_2', ax=ax)
plt.show()

# %%
fig, axes = plt.subplots(ncols=3, figsize=(20, 3))
axes[0].plot(df['wl'], df['2ms_1'])
axes[0].plot(df['wl'], df['2ms_2'])
axes[1].plot(df['wl'], df['200ms_1'])
axes[1].plot(df['wl'], df['200ms_2'])
axes[2].plot(df['wl'], df['thr_1'])
axes[2].plot(df['wl'], df['thr_2'])

#axes[0,0].set_xlim(655.5, 658)
#axes[0,1].set_xlim(485.5, 488)
#axes[0,2].set_xlim(432.5, 435)

for j in range(0, 3):
    axes[j].set_xlabel('Wavelength (nm)')
    axes[j].set_ylabel('Voltage (V)')
plt.show()
