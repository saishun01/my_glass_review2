# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('absorbance.csv')
df
# Out:
#          wl  baseline   buffer      gfp      yfp  lysozyme
# 0     550.0  -0.00041 -0.00013  0.00063  0.05395   0.02940
# 1     549.8  -0.00037 -0.00019  0.00072  0.05385   0.02947
# 2     549.6  -0.00030 -0.00007  0.00090  0.05364   0.02935
# 3     549.4  -0.00031  0.00005  0.00075  0.05356   0.02933
# 4     549.2  -0.00039  0.00010  0.00066  0.05354   0.02931
# ...     ...       ...      ...      ...      ...       ...
# 996   350.8  -0.00903 -0.00013  0.13144  0.18428   0.01779
# 997   350.6  -0.00901 -0.00016  0.13109  0.18453   0.01773
# 998   350.4  -0.00890 -0.00038  0.13091  0.18477   0.01768
# 999   350.2  -0.00885 -0.00051  0.13054  0.18478   0.01756
# 1000  350.0  -0.00912 -0.00020  0.13036  0.18510   0.01791
#
# [1001 rows x 6 columns]

# %%
plt.figure()
#ax = df.plot('wl', 'baseline')
ax = df.plot('wl', 'gfp', label='GFP')
df.plot('wl', 'yfp', ax=ax, label='YFP')
df.plot('wl', 'lysozyme', ax=ax, label='Lysozyme')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Absorbance')
plt.xlim(350,550)
plt.ylim(0,0.3)
plt.legend()
plt.show()

# %%
df.query('500 < wl & 0.114 < yfp')
# Out:
#         wl  baseline   buffer      gfp      yfp  lysozyme
# 194  511.2  -0.00178 -0.00004  0.00623  0.11429   0.02665
# 195  511.0  -0.00176 -0.00002  0.00614  0.11437   0.02669
# 196  510.8  -0.00164 -0.00030  0.00631  0.11436   0.02644
# 197  510.6  -0.00168 -0.00025  0.00666  0.11453   0.02641
# 198  510.4  -0.00177  0.00002  0.00690  0.11474   0.02631
# 199  510.2  -0.00179 -0.00007  0.00728  0.11475   0.02632
# 200  510.0  -0.00167 -0.00030  0.00749  0.11465   0.02634
# 201  509.8  -0.00174 -0.00015  0.00766  0.11490   0.02631
# 202  509.6  -0.00185 -0.00006  0.00794  0.11500   0.02644
# 203  509.4  -0.00182 -0.00008  0.00828  0.11467   0.02638
# 204  509.2  -0.00172 -0.00021  0.00853  0.11454   0.02619
# 205  509.0  -0.00183 -0.00018  0.00885  0.11479   0.02640
# 206  508.8  -0.00178 -0.00019  0.00910  0.11464   0.02617
# 207  508.6  -0.00182 -0.00006  0.00939  0.11468   0.02611
# 208  508.4  -0.00182 -0.00011  0.00963  0.11449   0.02613
# ...

# %% [markdown]
# ## memo
# gfp peak: 397.0, 0.26972
#
# yfp peak: 403.8, 0.27450 & 509.6, 0.11500
